# %%
pip install pydantic
# Out:
# Collecting pydantic
#   Downloading pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.0/68.0 kB 409.9 kB/s eta 0:00:00 kB/s eta 0:00:01:01
# Collecting annotated-types>=0.6.0 (from pydantic)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic)
#   Downloading pydantic_core-2.33.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: typing-extensions>=4.12.2 in ./venv/lib/python3.11/site-packages (from pydantic) (4.13.2)
# Collecting typing-inspection>=0.4.0 (from pydantic)
#   Downloading typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Downloading pydantic-2.11.7-py3-none-any.whl (444 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 444.8/444.8 kB 1.4 MB/s eta 0:00:001.3 MB/s eta 0:00:01m
# Downloading pydantic_core-2.33.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 2.5 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Installing collected packages: typing-inspection, pydantic-core, annotated-types, pydantic
# Successfully installed annotated-types-0.7.0 pydantic-2.11.7 pydantic-core-2.33.2 typing-inspection-0.4.1
#
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker, declarative_base

DATABASE_URL = "mysql+pymysql://root:@localhost:3306/pro_boost"

engine = create_engine(DATABASE_URL)
SessionLocal = sessionmaker(autocommit=False, autoflush=False, bind=engine)
Base = declarative_base()

# %%
from sqlalchemy import Column, Integer, String, Boolean, DateTime, Enum, Text, DECIMAL, ForeignKey
from sqlalchemy.sql import func
import enum
from datetime import datetime

class UserRole(enum.Enum):
    buyer = "buyer"
    pro = "pro"
    admin = "admin"

class User(Base):
    __tablename__ = "users"
    user_id = Column(Integer, primary_key=True, autoincrement=True)
    email = Column(String(255), unique=True, nullable=False)
    password_hash = Column(Text, nullable=False)
    role = Column(Enum('buyer', 'pro', 'admin'), nullable=False)
    name = Column(String(100), nullable=True)
    avatar_url = Column(Text, nullable=True)
    created_at = Column(DateTime, server_default=func.now())
    is_verified = Column(Boolean, default=False)
    status = Column(String(20), nullable=False, default='inactive')

class BlogPost(Base):
    __tablename__ = "blog_posts"
    post_id = Column(Integer, primary_key=True, index=True)
    author_id = Column(Integer, ForeignKey('users.user_id'), nullable=False)
    title = Column(String(255), nullable=True)
    slug = Column(String(255), unique=True, nullable=True)
    content = Column(Text, nullable=True)
    cover_image_url = Column(Text, nullable=True)
    created_at = Column(DateTime, default=datetime.utcnow)
    updated_at = Column(DateTime, nullable=True)

class BlogComment(Base):
    __tablename__ = "blog_comments"
    comment_id = Column(Integer, primary_key=True, index=True)
    post_id = Column(Integer, ForeignKey('blog_posts.post_id'), nullable=False)
    user_id = Column(Integer, ForeignKey('users.user_id'), nullable=True)
    content = Column(Text, nullable=True)
    created_at = Column(DateTime, default=datetime.utcnow)

class Game(Base):
    __tablename__ = "games"
    game_id = Column(Integer, primary_key=True, index=True)
    name = Column(String(100), nullable=False)
    icon_url = Column(Text, nullable=True)

class Service(Base):
    __tablename__ = "services"
    service_id = Column(Integer, primary_key=True, index=True)
    game_id = Column(Integer, ForeignKey('games.game_id'), nullable=False)
    name = Column(String(100), nullable=False)
    description = Column(Text, nullable=True)
    price_per_unit = Column(DECIMAL(10,2), nullable=True)
    icon_url = Column(Text, nullable=True)
    sale_price = Column(DECIMAL(10,2), nullable=True)
    category = Column(String(100), nullable=True)

class Order(Base):
    __tablename__ = "orders"
    order_id = Column(Integer, primary_key=True, index=True)
    buyer_id = Column(Integer, ForeignKey('users.user_id'), nullable=False)
    service_id = Column(Integer, ForeignKey('services.service_id'), nullable=False)
    game_id = Column(Integer, ForeignKey('games.game_id'), nullable=False)
    status = Column(Enum('pending','in_progress','completed','cancelled', name='order_status'), default='pending')
    details = Column(Text, nullable=True)
    created_at = Column(DateTime, default=datetime.utcnow)

class OrderAssignment(Base):
    __tablename__ = "order_assignments"
    assignment_id = Column(Integer, primary_key=True, index=True)
    order_id = Column(Integer, ForeignKey('orders.order_id'), nullable=False)
    pro_id = Column(Integer, ForeignKey('users.user_id'), nullable=False)
    assigned_at = Column(DateTime, default=datetime.utcnow)
    completed_at = Column(DateTime, nullable=True)
    remarks = Column(Text, nullable=True)

class ProApplication(Base):
    __tablename__ = "pro_applications"
    application_id = Column(Integer, primary_key=True, index=True)
    user_id = Column(Integer, ForeignKey('users.user_id'), nullable=False)
    experience = Column(Text, nullable=True)
    status = Column(Enum('pending','approved','rejected', name='application_status'), default='pending')
    submitted_at = Column(DateTime, default=datetime.utcnow)

class ChatMessage(Base):
    __tablename__ = "chat_messages"
    message_id = Column(Integer, primary_key=True, index=True)
    order_id = Column(Integer, ForeignKey('orders.order_id'), nullable=False)
    sender_id = Column(Integer, ForeignKey('users.user_id'), nullable=False)
    receiver_id = Column(Integer, ForeignKey('users.user_id'), nullable=False)
    message = Column(Text, nullable=False)
    sent_at = Column(DateTime, default=datetime.utcnow)

# %%
from pydantic import BaseModel
from sqlalchemy.orm import Session

def get_db():
    db = SessionLocal()
    try:
        yield db
    finally:
        db.close()

class GameCreate(BaseModel):
    name: str
    icon_url: str = None

# %%
db = next(get_db())

# %%
# create pandas dataframe get all game Name from folder gamesTwo
import os
import pandas as pd
gamesTwo_files = set(os.listdir("gamesTwo"))
all_games = []
for file_name in gamesTwo_files:
    df = pd.read_csv(f'./gamesTwo/{file_name}')
    all_games.append(df.iloc[0,0])

# %%
import re
import requests
gamesTwo_images = list(os.listdir("game_services"))
gamesTwo_images.sort()
errored = []
all_images = []
for game in gamesTwo_images:
    match = re.search(r"skycoach_results_(.*?)_services\.csv(?:\.csv)?", game)

    if match:
        game_name = match.group(1).replace('_', ' ')
        print(game_name)  # Output: 8 Ball Pool
    try:
        df = pd.read_csv(f'./game_services/{game}')
        print(df.iloc[0,6])
        all_images.append(df.iloc[0,6])
    except Exception as e:
        print(f"Error reading {game}: {e}")
        game_instance = Game(name=game_name, icon_url="")
        # db.add(game_instance)
        # db.commit()
        # db.refresh(game_instance)
        # print(f"Added game: {game_name} without icon URL due to error: {e}")
        errored.append(game)
        continue
    if df.empty:
        print(f"Skipping empty dataframe for {game_name}")
        continue
    # break

    # game_instance = Game(name=game_name, icon_url=df.iloc[0,6])
    # db.add(game_instance)
    # db.commit()
    # db.refresh(game_instance)
    # print(f"Added game: {game_name} with icon URL: {df.iloc[0,6]}")

for game_image in all_images:
    try:
        response = requests.get(game_image)
        # save in lcoal
        with open(f'./game_images/{game_image.split("/")[-1]}', 'wb') as f:
            f.write(response.content)
        # Check if the image exists
        print(f"Checking image: {game_image}")
        response = requests.head(game_image)
        if response.status_code == 200:
            
            print(f"Image {game_image} exists.")
        else:
            print(f"Image {game_image} does not exist. Status code: {response.status_code}")
    except requests.RequestException as e:
        print(f"
    if match:
        game_name = match.group(1).replace('_', ' ')
        print(game_name)  # Output: 8 Ball Pool
    try:
        df = pd.read_csv(f'./game_services/{game}')
        print(df.iloc[0,6])
    except Exception as e:
        print(f"Error reading {game}: {e}")
        game_instance = Game(name=game_name, icon_url="")
        db.add(game_instance)
        db.commit()
        db.refresh(game_instance)
        print(f"Added game: {game_name} without icon URL due to error: {e}")
        errored.append(game)
        continue
    if df.empty:
        print(f"Skipping empty dataframe for {game_name}")
        continue
    # break

    game_instance = Game(name=game_name, icon_url=df.iloc[0,6])
    db.add(game_instance)
    db.commit()
    db.refresh(game_instance)
    print(f"Added game: {game_name} with icon URL: {df.iloc[0,6]}")
# Out:
# 8 Ball Pool
# Error reading skycoach_results_8_Ball_Pool_services.csv.csv: No columns to parse from file
# Added game: 8 Ball Pool without icon URL due to error: No columns to parse from file
# ARC Raiders
# https://skycoach.gg/storage/uploads/products/arc-raiders-dam-battlegrounds-raid1749064142_picture_item.png
# Added game: ARC Raiders with icon URL: https://skycoach.gg/storage/uploads/products/arc-raiders-dam-battlegrounds-raid1749064142_picture_item.png
# Albion Online
# https://skycoach.gg/storage/uploads/products/albion-online-tomes-of-insights1736542026_picture_item.png
# Added game: Albion Online with icon URL: https://skycoach.gg/storage/uploads/products/albion-online-tomes-of-insights1736542026_picture_item.png
# Apex Legends
# https://skycoach.gg/storage/uploads/products/ranked-rumble-boost1722685907_picture_item.png
# Added game: Apex Legends with icon URL: https://skycoach.gg/storage/uploads/products/ranked-rumble-boost1722685907_picture_item.png
# Arena Breakout- Infinite
# https://skycoach.gg/storage/uploads/products/abi-raids-boost1723469655_picture_item.png
# Added game: Arena Breakout- Infinite with icon URL: https://skycoach.gg/storage/uploads/products/abi-raids-boost1723469655_picture_item.png
# Ashes of Creation
# https://skycoach.gg/storage/uploads/products/aoc-rogue-build1744896612_picture_item.png
# Added game: Ashes of Creation with icon URL: https://skycoach.gg/storage/uploads/products/aoc-rogue-build1744896612_picture_item.png
# Black Desert Online
# https://skycoach.gg/storage/uploads/products/bdo-season-pass-boost-full-completion1698783753_picture_item.png
# Added game: Black Desert Online with icon URL: https://skycoach.gg/storage/uploads/products/bdo-season-pass-boost-full-completion1698783753_picture_item.png
# Blade & Soul NEO
# https://skycoach.gg/storage/uploads/products/blade-soul-neo-quests-boost1742920941_picture_item.png
# Added game: Blade & Soul NEO with icon URL: https://skycoach.gg/storage/uploads/products/blade-soul-neo-quests-boost1742920941_picture_item.png
# Brawl Stars
# https://skycoach.gg/storage/uploads/products/championship-challenge-boost1739977007_picture_item.png
# Added game: Brawl Stars with icon URL: https://skycoach.gg/storage/uploads/products/championship-challenge-boost1739977007_picture_item.png
# Call of Duty Mobile
# https://skycoach.gg/storage/uploads/products/cod-mobile-damascus-camo1714391773_picture_item.png
# Added game: Call of Duty Mobile with icon URL: https://skycoach.gg/storage/uploads/products/cod-mobile-damascus-camo1714391773_picture_item.png
# Call of Duty
# https://skycoach.gg/storage/uploads/products/cod-hourly-boosting1731320816_picture_item.png
# Added game: WoW Cataclysm with icon URL: https://skycoach.gg/storage/uploads/products/madness-of-deathwing-normal-kill1716069209_picture_item.png
# WoW Classic 20th Anniversary
# Error reading skycoach_results_WoW_Classic_20th_Anniversary_services.csv.csv: No columns to parse from file
# Added game: WoW Classic 20th Anniversary without icon URL due to error: No columns to parse from file
# WoW Classic Era
# https://skycoach.gg/storage/uploads/products/mining1692836423_picture_item.png
# Added game: WoW Classic Era with icon URL: https://skycoach.gg/storage/uploads/products/mining1692836423_picture_item.png
# WoW Classic Hardcore
# https://skycoach.gg/storage/uploads/products/wow-hardcore-blackrock-depths-boost1689498048_picture_item.png
# Added game: WoW Classic Hardcore with icon URL: https://skycoach.gg/storage/uploads/products/wow-hardcore-blackrock-depths-boost1689498048_picture_item.png
# WoW Mists of Pandaria Classic
# https://skycoach.gg/storage/uploads/products/scarlet-halls-dungeon-boost1734013003_picture_item.png
# Added game: WoW Mists of Pandaria Classic with icon URL: https://skycoach.gg/storage/uploads/products/scarlet-halls-dungeon-boost1734013003_picture_item.png
# WoW Season of Discovery
# https://skycoach.gg/storage/uploads/products/season-of-discovery-powerleveling1699144115_picture_item.png
# Added game: WoW Season of Discovery with icon URL: https://skycoach.gg/storage/uploads/products/season-of-discovery-powerleveling1699144115_picture_item.png
# World of Tanks
# https://skycoach.gg/storage/uploads/products/personal-missions-10-object-260-campaign1707514743_picture_item.png
# Added game: World of Tanks with icon URL: https://skycoach.gg/storage/uploads/products/personal-missions-10-object-260-campaign1707514743_picture_item.png
# World of Warcraft
# https://skycoach.gg/storage/uploads/products/mad-world-achievement1742307138_picture_item.png
# Added game: World of Warcraft with icon URL: https://skycoach.gg/storage/uploads/products/mad-world-achievement1742307138_picture_item.png
# Wuthering Waves
# https://skycoach.gg/storage/uploads/products/huanglong-100-exploration1749820138_picture_item.png
# Added game: Wuthering Waves with icon URL: https://skycoach.gg/storage/uploads/products/huanglong-100-exploration1749820138_picture_item.png
# Zenless Zone Zero
# https://skycoach.gg/storage/uploads/products/main-quests-boost1721211408_picture_item.png
# Added game: Zenless Zone Zero with icon URL: https://skycoach.gg/storage/uploads/products/main-quests-boost1721211408_picture_item.png

# %%
all_games.sort()
all_games
# Out:
# ['8 Ball Pool',
#  'ARC Raiders',
#  'Albion Online',
#  'Apex Legends',
#  'Arena Breakout- Infinite',
#  'Ashes of Creation',
#  'Black Desert Online',
#  'Blade & Soul NEO',
#  'Brawl Stars',
#  'Call of Duty',
#  'Call of Duty Mobile',
#  'Clash Royale',
#  'Clash of Clans',
#  'Corepunk',
#  'Counter-Strike 2',
#  'Dark and Darker',
#  'Dead by Daylight',
#  'Deadlock',
#  'Delta Force Hawk Ops',
#  'Destiny 2',
#  'Diablo 4',
#  'Diablo Immortal',
#  'Division 2',
#  'Dota 2',
#  'Dragon Ball Legends',
#  'Dune- Awakening',
#  'EVE Online',
#  'Elden Ring',
#  'Elden Ring Nightreign',
#  'Escape from Tarkov',
#  'FC 25',
#  'Fallout 76',
#  'Final Fantasy XIV',
#  'Fortnite',
#  'Forza Horizon 5',
#  'FragPunk',
#  'Genshin Impact',
#  'GoT Kingsroad',
#  'Guild Wars 2',
#  'Hay Day',
#  'Hearthstone',
#  'Helldivers 2',
#  'Honkai Star Rail',
#  'Hunt Showdown',
#  'Last Epoch',
#  'League of Legends',
#  'Lost Ark',
#  'MapleStory',
#  'Marvel Rivals',
#  'Minecraft',
#  'MoCo',
#  'Mobile Legends',
#  'Monopoly Go',
#  'Monster Hunter Wilds',
#  'NBA',
#  'New World',
#  'Old School RuneScape',
#  'Once Human',
#  'One Piece Bounty Rush',
#  'Overwatch 2',
#  'PUBG Mobile',
#  'Palia',
#  'Palworld',
#  'Path of Exile',
#  'Path of Exile 2',
#  'Pax Dei',
#  'Pokemon GO',
#  'Quinfall',
#  'RAID- Shadow Legends',
#  'RBLX',
#  'Rainbow Six Siege',
#  'Ravendawn Online',
#  'Red Dead Redemption 2',
#  'Rematch',
#  'Remnant 2',
#  'Rocket League',
#  'RuneScape',
#  'RuneScape Dragonwilds',
#  'Rust',
#  'Sea of Thieves',
#  'Squad Busters',
#  'Star Wars- The Old Republic',
#  'Summoners War',
#  'Tarisland',
#  'Teamfight Tactics',
#  'The Elder Scrolls Online',
#  'The Finals',
#  'The First Descendant',
#  'Throne and Liberty',
#  'Tower of Fantasy',
#  'Valorant',
#  'Warcraft Rumble',
#  'Warframe',
#  'Warhammer 40000 Space Marine 2',
#  'Warhammer 40000- Darktide',
#  'WoW Cataclysm',
#  'WoW Classic 20th Anniversary',
#  'WoW Classic Era',
#  'WoW Classic Hardcore',
#  'WoW Mists of Pandaria Classic',
#  'WoW Season of Discovery',
#  'World of Tanks',
#  'World of Warcraft',
#  'Wuthering Waves',
#  'Zenless Zone Zero']

# %%
def extract_numeric(value):
    import re
    if not isinstance(value, str):
        return None
    match = re.findall(r'[\d,\.]+', value)
    if not match:
        return None
    return float(match[0].replace(',', '.'))

# %%
# save the services of games by getting game id
db = next(get_db())
all_games = list(os.listdir("game_services"))
errored_games
for game in all_games:
    try:
        game_name = game.replace('skycoach_results_', '').replace('_services.csv.csv', '').replace('_', ' ')
        print(game_name)
        if game_name == 'Last Epoch':
            continue  # Skip Last Epoch as per the original code logic
        game_instance = db.query(Game).filter(Game.name == game_name).first()
        print('game instance')
        if not game_instance:
            print(f"Game {game} not found in database.")
            continue
        df = pd.read_csv(f'./game_services/{game}')
        for index, row in df.iterrows():
            service_instance = Service(
                game_id=game_instance.game_id,
                name=row['Name'],
                description=row['Description'],
                price_per_unit=extract_numeric(row['Price']),
                icon_url=row['GameCharImage'],
                sale_price=row.get('sale_price', 0.0),
                category=row.get('Category', "")
            )
            db.add(service_instance)
        db.commit()
        db.refresh(game_instance)
        print(f"Added services for game: {game}")
    except Exception as e:
        print(f"Error processing game {game}: {e}")
    # print(game)
    # break
# Out:
# Last Epoch
# Old School RuneScape
# game instance
# Added services for game: skycoach_results_Old_School_RuneScape_services.csv.csv
# WoW Mists of Pandaria Classic
# game instance
# Error processing game skycoach_results_WoW_Mists_of_Pandaria_Classic_services.csv.csv: could not convert string to float: '2.699.99'
# Zenless Zone Zero
# game instance
# Added services for game: skycoach_results_Zenless_Zone_Zero_services.csv.csv
# Lost Ark
# game instance
# Added services for game: skycoach_results_Lost_Ark_services.csv.csv
# World of Warcraft
# game instance
# Error processing game skycoach_results_World_of_Warcraft_services.csv.csv: could not convert string to float: '1.799.99'
# Tarisland
# game instance
# Error processing game skycoach_results_Tarisland_services.csv.csv: could not convert string to float: '1.099.99'
# Rematch
# game instance
# Added services for game: skycoach_results_Rematch_services.csv.csv
# Tower of Fantasy
# game instance
# Added services for game: skycoach_results_Tower_of_Fantasy_services.csv.csv
# Warcraft Rumble
# game instance
# Added services for game: skycoach_results_Warcraft_Rumble_services.csv.csv
# EVE Online
# game instance
# Added services for game: skycoach_results_EVE_Online_services.csv.csv
# Diablo Immortal
# game instance
# Added services for game: skycoach_results_Diablo_Immortal_services.csv.csv
# The First Descendant
# game instance
# Added services for game: skycoach_results_The_First_Descendant_services.csv.csv
# Clash of Clans
# game instance
# Added services for game: skycoach_results_Clash_of_Clans_services.csv.csv
# Dead by Daylight
# game instance
# Added services for game: skycoach_results_Dead_by_Daylight_services.csv.csv
# WoW Season of Discovery
# game instance
# Error processing game skycoach_results_WoW_Season_of_Discovery_services.csv.csv: could not convert string to float: '1.899.99'
# Deadlock
# game instance
# Error processing game skycoach_results_Deadlock_services.csv.csv: No columns to parse from file
# Rocket League
# game instance
# Error processing game skycoach_results_Rocket_League_services.csv.csv: No columns to parse from file
# Black Desert Online
# game instance
# Added services for game: skycoach_results_Black_Desert_Online_services.csv.csv
# Dune- Awakening
# game instance
# Added services for game: skycoach_results_Dune-_Awakening_services.csv.csv
# Call of Duty Mobile
# game instance
# Added services for game: skycoach_results_Call_of_Duty_Mobile_services.csv.csv
# Guild Wars 2
# game instance
# Added services for game: skycoach_results_Guild_Wars_2_services.csv.csv
# Blade & Soul NEO
# game instance
# Added services for game: skycoach_results_Blade_&_Soul_NEO_services.csv.csv
# Rust
# game instance
# Added services for game: skycoach_results_Rust_services.csv.csv
# RAID- Shadow Legends
# game instance
# Error processing game skycoach_results_RAID-_Shadow_Legends_services.csv.csv: No columns to parse from file
# Summoners War
# game instance
# Error processing game skycoach_results_Summoners_War_services.csv.csv: No columns to parse from file
# Mobile Legends
# game instance
# Added services for game: skycoach_results_Mobile_Legends_services.csv.csv
# Clash Royale
# game instance
# Added services for game: skycoach_results_Clash_Royale_services.csv.csv
# Warhammer 40000- Darktide
# game instance
# Added services for game: skycoach_results_Warhammer_40000-_Darktide_services.csv.csv
# Remnant 2
# game instance
# Added services for game: skycoach_results_Remnant_2_services.csv.csv
# Warframe
# game instance
# Added services for game: skycoach_results_Warframe_services.csv.csv
# Minecraft
# game instance
# Added services for game: skycoach_results_Minecraft_services.csv.csv
# Call of Duty
# game instance
# Error processing game skycoach_results_Call_of_Duty_services.csv.csv: could not convert string to float: '1.474.99'
# New World
# game instance
# Added services for game: skycoach_results_New_World_services.csv.csv
# Apex Legends
# game instance
# Added services for game: skycoach_results_Apex_Legends_services.csv.csv
# Brawl Stars
# game instance
# Added services for game: skycoach_results_Brawl_Stars_services.csv.csv
# Forza Horizon 5
# game instance
# Added services for game: skycoach_results_Forza_Horizon_5_services.csv.csv
# Path of Exile
# game instance
# Added services for game: skycoach_results_Path_of_Exile_services.csv.csv
# Squad Busters
# game instance
# Added services for game: skycoach_results_Squad_Busters_services.csv.csv
# Quinfall
# game instance
# Added services for game: skycoach_results_Quinfall_services.csv.csv
# Dota 2
# game instance
# Added services for game: skycoach_results_Dota_2_services.csv.csv
# Teamfight Tactics
# game instance
# Added services for game: skycoach_results_Teamfight_Tactics_services.csv.csv
# Escape from Tarkov
# game instance
# Error processing game skycoach_results_Escape_from_Tarkov_services.csv.csv: could not convert string to float: '1.034.99'
# Honkai Star Rail
# game instance
# Added services for game: skycoach_results_Honkai_Star_Rail_services.csv.csv
# Corepunk
# game instance
# Added services for game: skycoach_results_Corepunk_services.csv.csv
# RBLX
# game instance
# Added services for game: skycoach_results_RBLX_services.csv.csv
# Ravendawn Online
# game instance
# Error processing game skycoach_results_Ravendawn_Online_services.csv.csv: No columns to parse from file
# Hunt Showdown
# game instance
# Added services for game: skycoach_results_Hunt_Showdown_services.csv.csv
# RuneScape
# game instance
# Added services for game: skycoach_results_RuneScape_services.csv.csv
# FragPunk
# game instance
# Added services for game: skycoach_results_FragPunk_services.csv.csv
# Final Fantasy XIV
# game instance
# Added services for game: skycoach_results_Final_Fantasy_XIV_services.csv.csv
# Palworld
# game instance
# Added services for game: skycoach_results_Palworld_services.csv.csv
# Star Wars- The Old Republic
# game instance
# Added services for game: skycoach_results_Star_Wars-_The_Old_Republic_services.csv.csv
# Valorant
# game instance
# Error processing game skycoach_results_Valorant_services.csv.csv: No columns to parse from file
# Dark and Darker
# game instance
# Added services for game: skycoach_results_Dark_and_Darker_services.csv.csv
# Overwatch 2
# game instance
# Added services for game: skycoach_results_Overwatch_2_services.csv.csv
# 8 Ball Pool
# game instance
# Error processing game skycoach_results_8_Ball_Pool_services.csv.csv: No columns to parse from file
# Ashes of Creation
# game instance
# Added services for game: skycoach_results_Ashes_of_Creation_services.csv.csv
# Monopoly Go
# game instance
# Added services for game: skycoach_results_Monopoly_Go_services.csv.csv
# Genshin Impact
# game instance
# Added services for game: skycoach_results_Genshin_Impact_services.csv.csv
# Elden Ring Nightreign
# game instance
# Added services for game: skycoach_results_Elden_Ring_Nightreign_services.csv.csv
# Counter-Strike 2
# game instance
# Error processing game skycoach_results_Counter-Strike_2_services.csv.csv: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# Pax Dei
# Error processing game skycoach_results_Pax_Dei_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# Hay Day
# Error processing game skycoach_results_Hay_Day_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# Throne and Liberty
# Error processing game skycoach_results_Throne_and_Liberty_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# Fallout 76
# Error processing game skycoach_results_Fallout_76_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# FC 25
# Error processing game skycoach_results_FC_25_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# WoW Cataclysm
# Error processing game skycoach_results_WoW_Cataclysm_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# Path of Exile 2
# Error processing game skycoach_results_Path_of_Exile_2_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# The Elder Scrolls Online
# Error processing game skycoach_results_The_Elder_Scrolls_Online_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# Hearthstone
# Error processing game skycoach_results_Hearthstone_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# MapleStory
# Error processing game skycoach_results_MapleStory_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# WoW Classic Era
# Error processing game skycoach_results_WoW_Classic_Era_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# Albion Online
# Error processing game skycoach_results_Albion_Online_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# The Finals
# Error processing game skycoach_results_The_Finals_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# Delta Force Hawk Ops
# Error processing game skycoach_results_Delta_Force_Hawk_Ops_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# Sea of Thieves
# Error processing game skycoach_results_Sea_of_Thieves_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# Monster Hunter Wilds
# Error processing game skycoach_results_Monster_Hunter_Wilds_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# Marvel Rivals
# Error processing game skycoach_results_Marvel_Rivals_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# NBA
# Error processing game skycoach_results_NBA_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# WoW Classic 20th Anniversary
# Error processing game skycoach_results_WoW_Classic_20th_Anniversary_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# Warhammer 40000 Space Marine 2
# Error processing game skycoach_results_Warhammer_40000_Space_Marine_2_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# Elden Ring
# Error processing game skycoach_results_Elden_Ring_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# Arena Breakout- Infinite
# Error processing game skycoach_results_Arena_Breakout-_Infinite_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# PUBG Mobile
# Error processing game skycoach_results_PUBG_Mobile_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# Fortnite
# Error processing game skycoach_results_Fortnite_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# Rainbow Six Siege
# Error processing game skycoach_results_Rainbow_Six_Siege_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# One Piece Bounty Rush
# Error processing game skycoach_results_One_Piece_Bounty_Rush_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# GoT Kingsroad
# Error processing game skycoach_results_GoT_Kingsroad_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# Red Dead Redemption 2
# Error processing game skycoach_results_Red_Dead_Redemption_2_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# Diablo 4
# Error processing game skycoach_results_Diablo_4_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# Palia
# Error processing game skycoach_results_Palia_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# Wuthering Waves
# Error processing game skycoach_results_Wuthering_Waves_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# Dragon Ball Legends
# Error processing game skycoach_results_Dragon_Ball_Legends_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# World of Tanks
# Error processing game skycoach_results_World_of_Tanks_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# MoCo
# Error processing game skycoach_results_MoCo_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# Once Human
# Error processing game skycoach_results_Once_Human_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# Division 2
# Error processing game skycoach_results_Division_2_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# Destiny 2
# Error processing game skycoach_results_Destiny_2_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# ARC Raiders
# Error processing game skycoach_results_ARC_Raiders_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# WoW Classic Hardcore
# Error processing game skycoach_results_WoW_Classic_Hardcore_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# Pokemon GO
# Error processing game skycoach_results_Pokemon_GO_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# League of Legends
# Error processing game skycoach_results_League_of_Legends_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# Helldivers 2
# Error processing game skycoach_results_Helldivers_2_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
# RuneScape Dragonwilds
# Error processing game skycoach_results_RuneScape_Dragonwilds_services.csv.csv: This Session's transaction has been rolled back due to a previous exception during flush. To begin a new transaction with this Session, first issue Session.rollback(). Original exception was: (pymysql.err.ProgrammingError) nan can not be used with MySQL
# [SQL: INSERT INTO services (game_id, name, description, price_per_unit, icon_url, sale_price, category) VALUES (%(game_id)s, %(name)s, %(description)s, %(price_per_unit)s, %(icon_url)s, %(sale_price)s, %(category)s)]
# [parameters: {'game_id': 16, 'name': 'CS2 Accounts', 'description': nan, 'price_per_unit': None, 'icon_url': nan, 'sale_price': 0.0, 'category': 'Accounts'}]
# (Background on this error at: https://sqlalche.me/e/20/f405) (Background on this error at: https://sqlalche.me/e/20/7s2a)
